# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("creditcard.csv")
print(df.shape)
df.head()
# Out:
# (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_X = df.drop(['Class'], axis=1)
df_y = df['Class']

# %% [markdown]
# # Data Analysis
# ## Correlation map with raw data
# ## Undersampling of data
# ## Correlation map with new data
# ## Removal of redundant variables
# ## Boxplots analysis
# ## Distribution analysis

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Con downsample

# %%
from sklearn.datasets import make_classification
from imblearn.under_sampling import ClusterCentroids # doctest: +NORMALIZE_WHITESPACE
cc = ClusterCentroids(random_state=42)
X_res, y_res = cc.fit_resample(df_X, df_y)
print('Resampled dataset shape %s' % y_res.shape[0])
# Out:
# Resampled dataset shape 984

# %%
y_res.value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
f, ax = plt.subplots(figsize=(20, 20))
corrs = (X_res.join(y_res)).corr()
corrs = corrs.applymap(lambda x : abs(round(x, 2)))
sns.heatmap(corrs, annot=True, linewidths=.5, ax=ax)

# %%
#Sin downsample

# %%
f, ax = plt.subplots(figsize=(20, 20))
corrs = df.corr()
corrs = corrs.applymap(lambda x : abs(round(x, 2)))
sns.heatmap(corrs, annot=True, linewidths=.5, ax=ax)

# %%
#Removing highly correlated variables

#class_corrs = corrs['Class']
#class_corrs = (class_corrs[abs(class_corrs) > 0.5])[:-1]
#class_corrs = abs(class_corrs)
#class_corrs.sort_values(ascending=False)

features_corr = X_res.corr()
features_corr = features_corr.applymap(lambda x : abs(round(x, 2)))
cols = X_res.columns.tolist()
to_remove = []
for i in range(len(cols)-1):
    for j in range(i, len(cols)):
        if i != j and features_corr[cols[i]][cols[j]] >= 0.85:
            print(cols[i], " -> ", cols[j], " = ", features_corr[cols[i]][j])
            to_remove.append(cols[i])
            break
for i in to_remove:
    cols.remove(i)
# Out:
# V1  ->  V3  =  0.9
# V3  ->  V10  =  0.86
# V9  ->  V10  =  0.89
# V10  ->  V12  =  0.89
# V11  ->  V12  =  0.94
# V12  ->  V14  =  0.88
# V16  ->  V17  =  0.95
# V17  ->  V18  =  0.97

# %%
f, ax = plt.subplots(figsize=(15, 15))
corrs = (X_res[cols].join(y_res)).corr()
corrs = corrs.applymap(lambda x : abs(round(x, 2)))
sns.heatmap(corrs, annot=True, linewidths=.5, ax=ax)

# %%
features = class_corrs.index.tolist()

temp = X_res[cols]
#print(temp.shape)
sns.set(style="whitegrid")
for fea in cols:
    
    t = X_res.join(y_res)
    
    t_0 = t[t['Class'] == 0]
    t_0_q1 = t_0[fea].quantile(.25)
    t_0_q3 = t_0[fea].quantile(.75)
    t_0_iqr = t_0_q3 - t_0_q1
    t_0 = t_0[t_0[fea].between(t_0_q1 - 1.5*t_0_iqr, t_0_q3 + 1.5*t_0_iqr)]
    t_1 = t[t['Class'] == 1]
    t_1_q1 = t_1[fea].quantile(.25)
    t_1_q3 = t_1[fea].quantile(.75)
    t_1_iqr = t_1_q3 - t_1_q1
    t_1 = t_1[t_1[fea].between(t_1_q1 - 1.5*t_1_iqr, t_1_q3 + 1.5*t_1_iqr)]
    
    con = pd.concat([t_0, t_1])
    
    #good_keys = con.index.intersection(temp.index)
    #temp = temp.loc[good_keys]
    
    sns.boxplot(x="Class", y=fea, palette=["r", "g"],
            data=con)
    plt.show()

# %%
#good: V2, V4, V5, V6, V7, V8, V14, V18, V19, V20, V21, V27, V28, V29
#bad: V13, V15, V22, V23, V24, V25, V26

#Chosen: V2,V4, V6, V7, V14, V18, V19
temp.shape
# Out:
# (547, 22)

# %%
from scipy.stats import normaltest

fs = ['V2', 'V4', 'V6', 'V7', 'V14', 'V18', 'V19']
for i in fs:
    sns.distplot(temp[i], hist=False, color="g", kde_kws={"shade": True})
    plt.show()

# %% [markdown]
# # Oversampling & model creation

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_X[fs], df_y, test_size=0.33, random_state=42)
# Out:
# (284807, 7)
# (568630, 7)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_smote, y_smote = sm.fit_resample(X_train, y_train)

from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0).fit(X_smote, y_smote)

y_result = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-258-ac5c70425223> in <module>
#      13 #clf.score(X_smote, y_smote)
#      14 #explained_variance_score(y_test, y_result)
# ---> 15 print(classification_report(y_test, y_resutl))
#
# NameError: name 'classification_report' is not defined

# %% [markdown]
# # Model scoring

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(clf.score(X_smote, y_smote))
print(explained_variance_score(y_test, y_result))
print(confusion_matrix(y_test, y_result))
print(classification_report(y_test, y_result))
# Out:
# 0.9303374619502467
# 0.7289626916514771
# [[90588  3187]
#  [ 9758 84115]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93     93775
#            1       0.96      0.90      0.93     93873
#
#     accuracy                           0.93    187648
#    macro avg       0.93      0.93      0.93    187648
# weighted avg       0.93      0.93      0.93    187648
